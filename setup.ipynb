# %%
# %load_ext autoreload
# %autoreload 2
 
# Import Generic Libraries
import pickle
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import pyplot as plt

# Import Custom Modules
from observation_classes.combined_observation import CombinedObservation
from utils.calculate_obs_stats import calculate_index_stats, mask_pairing, numpy_masks, calc_iou_thresholds
from operations.collect_multiple_observations import complete_report


# Set Global Variables
CITY_SHORTLIST={
    'washington_dc': 4140963,
    'los_angeles': 5368361,
    'paris': 2988507,
    'london': 2643743,
    'copenhagen': 2618425,
    'bejing': 1816670,
    'rio': 3451190,
    'tokyo': 1850147,
    'sao_paulo': 3448439,
    'salvador': 3450554,
    'santiago': 3871336,
    'bogota': 3688689,
    'rome': 3169070,
    'berlin': 2950159,
    'warsaw': 756135,
    'stockholm': 2673730,
    'athens': 264371,
    'moscow': 524901,
    'cairo': 360630,
    'lagos': 2332459,
    'nairobi': 184745,
    'johannesburg': 993800,
    'casablanca': 2553604,
    'seoul': 1835848,
    'shanghai': 1796236,
    'jakarta': 1642911,
    'sydney': 2147714,
    'melbourne': 2158177,
    'new_york': 5128581,
    'chicago': 4887398,
    'houston': 	4699066,
    'phoenix': 5308655,
    'atlanta': 4180439,
}

# %% [markdown]
# # Main Testing Area

# %%
with open('saved_observations/collections/seoul.pkl', 'rb') as src:
    obs = pickle.load(src)

obs.reset_lst()
obs.reset_sentinel_indexes()

# %%
ndvi_valid, lst_valid = mask_pairing(obs.ndvi, obs.lst)

# %%
plt.hist(lst_valid, bins=1000)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('City Temperatures')
plt.show()

# %% [markdown]
# ### Determining the best way to express IOU

# %%
row = calc_iou_thresholds(obs, obs.savi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]
row

# %% [markdown]
# ### Exploring other Indexes

# %%
row = calc_iou_thresholds(obs, obs.ndvi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.ndvi, 
                              index_name='NDVI',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']
# Out:
# scene_mean_index: 0.12606485188007355
# scene_mean_lst: 32.876434326171875
# p-value: 0.0
# pearson_cor: -0.40193668007850647
# linear_regression_slope: -23.540539732352663
# fig: <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2058x1634 at 0x315D77250>
# iou: 0.5566159984084396
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2058x1634>

# %%
row = calc_iou_thresholds(obs, obs.ndvi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.ndvi, 
                              index_name='NDVI Local',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh,
                              local_mean=True
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 5
#       1 row = calc_iou_thresholds(obs, obs.ndvi)
#       2 lst_thresh = row['lst_threshold'].values[0]
#       3 index_thresh = row['index_threshold'].values[0]
#       4
# ----> 5 stats = calculate_index_stats(obs,
#       6                               obs.ndvi,
#       7                               index_name='NDVI Local',
#       8                               iou_index_thresh=index_thresh,
#
# File <string>:3, in calculate_index_stats(obs, index, return_figure, iou_lst_thresh, iou_index_thresh, index_name, local_mean)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: 'bool' object is not callable

# %%
row = calc_iou_thresholds(obs, obs.savi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.savi, 
                              index_name='SAVI',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']

# %%
row = calc_iou_thresholds(obs, obs.savi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.savi, 
                              index_name='SAVI Local',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh,
                              local_mean=True
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']

# %%
row = calc_iou_thresholds(obs, obs.fvc)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.fvc, 
                              index_name='FVC',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']

# %%
row = calc_iou_thresholds(obs, obs.fvc)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.fvc, 
                              index_name='FVC Local',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh,
                              local_mean=True
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']

# %%
row = calc_iou_thresholds(obs, obs.ndmi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.ndmi, 
                              index_name='NDMI',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']

# %%
row = calc_iou_thresholds(obs, obs.ndmi)
lst_thresh = row['lst_threshold'].values[0]
index_thresh = row['index_threshold'].values[0]

stats = calculate_index_stats(obs, 
                              obs.ndmi, 
                              index_name='NDMI Local',
                              iou_index_thresh=index_thresh,
                              iou_lst_thresh=lst_thresh,
                              local_mean=True
                              )
for k, v in stats.items(): print(f'{k}: {v}')
stats['fig']
